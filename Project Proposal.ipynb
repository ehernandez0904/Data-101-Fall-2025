# %% [markdown]
# ### Project Proposals (individual work)
# Your project proposal should reflect your own individual work and should not overlap too much with the work of your peers. Project proposals should take the form of a JupyterLab notebook that includes the following sections:
#
# #### Introduction and Background for the problem you are interested in.
# ##### What is the question you hope you can answer?
# ##### Why is the question important to you?
# ##### What are you hoping to achieve with the project?
# #### Description of the data.
# ##### Where did you get your data?
# ##### What data is found in your data set?
# ##### Are there any ethical concerns with using the data or how the data was obtained?
# ##### Is there a public location where the data is freely available? If so where? If not why?
# #### Initial Exploratory Data Analysis
# ##### Definition of all variables (or explanation for why you are not considering some variables)
# ##### Descriptive statistics for the data set, counts of the variables, value counts (frequency tables) for each categorical variable of interest.
# ##### Plots that help a reader understand your data.
# ##### Initial analysis to answer initial data questions.
# #### Proposal for further study.
# ##### What larger questions would you like to try to answer?
# ##### What predictive analysis do you think might be possible?
# ##### Are there any larger impacts that your study might have?

# %% [markdown]
# #### Title

# %% [markdown]
# Analyzing Lifestyle Factors Associated with Heart Disease Link

# %% [markdown]
# #### Introduction & Background

# %% [markdown]
# Question: What lifestyle and demographic factors are most strongly associated with heart disease risk in adults?

# %% [markdown]
# #### Why It's Important

# %% [markdown]
# Heart disease is one of the leading causes of death. identifying the lifestyle factors most correlated with risk like smoking, physical activity or diet can help guide public health recommendations and individual preventive measures.

# %% [markdown]
# #### What I Hope to Achieve

# %% [markdown]
# I want to understand how everyday habits contribute to heart disease risk and build a simple predicitive model to estimate a person's risk based on their lifestyle and demographic information.

# %% [markdown]
# #### Description of the Data

# %% [markdown]
# The data comes from the CDC Behavioral Risk Factor Surveillance System (BRFSS) on Kaggle .https://www.kaggle.com/datasets/cdc/behavioral-risk-factor-surveillance-system
#
# The data set includes self-reported health and lifestyle information such as:
# - Heart disease
# - BMI
# - Smoking
# - Alcohol Drinking
# - Physical Activity
# - Sleep Time
# - Age
# - Sex
# - Diabetic
#
# The data set is collected through voluntary public surveys but doesn't have any personal information that is included.

# %% [markdown]
# #### Initial Exploratory Data Analysis

# %% [markdown]
# All the variables that I listed are focused on both continuous numerical and categorical features. Mean and Standard Deviation are on the data set for continous variables. Frequency counts for categorical variables are available. We also see a bar chart showing heart disease prevalence by gender and a boxplot of BMI grouby by heart disease status.
#
# Some initial questions to explore are:
# - How do rates of heart disease differ by age, gender, or diabetes status?
# - Is there a relationship between sleep duration and heart disease?
# - Are smokers or physically inactive individuals more likely to have heart disease?

# %% [markdown]
# #### Proposal for Further Study

# %% [markdown]
# Some larger questions to consider:
# - Can we predict heart disease risk using a combination of lifestyle and demographic factors?
# - Which single variable is the strongest predictor of heart disease?
#
# I plan to use maybe like logistic regression to predict the probability of heart disease. this analysis will holpefully help determine which variables are more important or significant in the dat
